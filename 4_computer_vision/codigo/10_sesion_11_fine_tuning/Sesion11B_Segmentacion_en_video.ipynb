# %% [markdown]
# # Probemos segmentación de objetos en un video pre‑guardado
#
# 1. **Sube tu video** desde el panel lateral ▸ *Archivos* ▸ **Subir**.
# 2. Ajusta el nombre del archivo en la celda *Configuración* si es diferente.
# 3. Ejecuta todas las celdas en orden

# %%
# !pip -q install ultralytics  # Instalamos Ultralytics (YOLOv8‑Seg)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 55.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 53.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 24.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.6 MB/s eta 0:00:00

# %% [markdown]
# ## Importamos librerías

# %%
from ultralytics import YOLO
from pathlib import Path
from IPython.display import HTML
from base64 import b64encode
import os, shutil
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# # (A) Configuración

# %%
INPUT_VIDEO  = "Sesion11_video.mp4"   # Cambia nombre de archivo
MODEL_PATH   = "yolov8n-seg.pt"
CONF_THRESH  = 0.25                   # confianza mínima
IOU_THRESH   = 0.45                   # IoU para NMS

# Verificamos la existencia del video
assert Path(INPUT_VIDEO).exists(), f"No se encontró {INPUT_VIDEO}."
print("Video encontrado:", INPUT_VIDEO)
# Out:
# Video encontrado: Sesion12_video.mp4

# %% [markdown]
# # (B) Cargar modelo y procesar video

# %%
# Cargar modelo
model = YOLO(MODEL_PATH)
print(f"Modelo {MODEL_PATH} cargado")

# Procesar video
results = model.predict(
    source = INPUT_VIDEO,
    conf   = CONF_THRESH,
    iou    = IOU_THRESH,
    save   = True,      # guarda video segmentado en runs/segment/
    half   = True,
    stream = False,
    boxes=False,
)

# Ubicar el archivo de salida más reciente
out_dir = Path("runs/segment")
print(f"Video procesado guardado en:\n{out_dir}")
# output_video = max(out_dir.glob("*/" + Path(INPUT_VIDEO).stem + ".mp4"), key=os.path.getmtime)
# print("Salida guardada en:", output_video)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n-seg.pt to 'yolov8n-seg.pt'...
# 100%|██████████| 6.74M/6.74M [00:00<00:00, 75.3MB/s]
# Modelo yolov8n-seg.pt cargado
# WARNING ⚠️ 'boxes' is deprecated and will be removed in in the future. Use 'show_boxes' instead.
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/50) /content/Sesion12_video.mp4: 384x640 3 persons, 7336.5ms
# video 1/1 (frame 2/50) /content/Sesion12_video.mp4: 384x640 3 persons, 7866.3ms
# video 1/1 (frame 3/50) /content/Sesion12_video.mp4: 384x640 4 persons, 7306.8ms
# video 1/1 (frame 4/50) /content/Sesion12_video.mp4: 384x640 4 persons, 7957.6ms
# video 1/1 (frame 5/50) /content/Sesion12_video.mp4: 384x640 3 persons, 7887.6ms
# video 1/1 (frame 6/50) /content/Sesion12_video.mp4: 384x640 3 persons, 6813.7ms
# video 1/1 (frame 7/50) /content/Sesion12_video.mp4: 384x640 3 persons, 7877.5ms
# video 1/1 (frame 8/50) /content/Sesion12_video.mp4: 384x640 3 persons, 7618.2ms
# video 1/1 (frame 9/50) /content/Sesion12_video.mp4: 384x640 3 persons, 7236.2ms
# video 1/1 (frame 10/50) /content/Sesion12_video.mp4: 384x640 3 persons, 7810.0ms
# video 1/1 (frame 11/50) /content/Sesion12_video.mp4: 384x640 4 persons, 6849.2ms
# video 1/1 (frame 12/50) /content/Sesion12_video.mp4: 384x640 3 persons, 8008.9ms
# video 1/1 (frame 13/50) /content/Sesion12_video.mp4: 384x640 3 persons, 7870.7ms
# video 1/1 (frame 14/50) /content/Sesion12_video.mp4: 384x640 3 persons, 7653.8ms
# video 1/1 (frame 15/50) /content/Sesion12_video.mp4: 384x640 3 persons, 8215.6ms
# video 1/1 (frame 16/50) /content/Sesion12_video.mp4: 384x640 3 persons, 7441.9ms
# video 1/1 (frame 17/50) /content/Sesion12_video.mp4: 384x640 7 persons, 8089.8ms
# video 1/1 (frame 18/50) /content/Sesion12_video.mp4: 384x640 8 persons, 7965.2ms
# video 1/1 (frame 19/50) /content/Sesion12_video.mp4: 384x640 8 persons, 7051.0ms
# video 1/1 (frame 20/50) /content/Sesion12_video.mp4: 384x640 9 persons, 8172.8ms
# video 1/1 (frame 21/50) /content/Sesion12_video.mp4: 384x640 9 persons, 7432.6ms
# video 1/1 (frame 22/50) /content/Sesion12_video.mp4: 384x640 8 persons, 7677.1ms
# video 1/1 (frame 23/50) /content/Sesion12_video.mp4: 384x640 9 persons, 8153.5ms
# video 1/1 (frame 24/50) /content/Sesion12_video.mp4: 384x640 9 persons, 1 backpack, 6899.2ms
# video 1/1 (frame 25/50) /content/Sesion12_video.mp4: 384x640 11 persons, 7864.6ms
# video 1/1 (frame 26/50) /content/Sesion12_video.mp4: 384x640 8 persons, 1 chair, 7811.9ms
# video 1/1 (frame 27/50) /content/Sesion12_video.mp4: 384x640 8 persons, 1 backpack, 1 suitcase, 6916.0ms
# video 1/1 (frame 28/50) /content/Sesion12_video.mp4: 384x640 9 persons, 1 chair, 7775.4ms
# video 1/1 (frame 29/50) /content/Sesion12_video.mp4: 384x640 8 persons, 6837.0ms
# video 1/1 (frame 30/50) /content/Sesion12_video.mp4: 384x640 8 persons, 7846.2ms
# video 1/1 (frame 31/50) /content/Sesion12_video.mp4: 384x640 10 persons, 2 chairs, 1 laptop, 1 oven, 7975.9ms
# video 1/1 (frame 32/50) /content/Sesion12_video.mp4: 384x640 8 persons, 1 chair, 1 dining table, 1 oven, 7965.5ms
# video 1/1 (frame 33/50) /content/Sesion12_video.mp4: 384x640 7 persons, 2 chairs, 1 oven, 8057.8ms
# video 1/1 (frame 34/50) /content/Sesion12_video.mp4: 384x640 8 persons, 4 chairs, 1 dining table, 1 oven, 8347.8ms
# video 1/1 (frame 35/50) /content/Sesion12_video.mp4: 384x640 9 persons, 4 chairs, 1 dining table, 1 oven, 6992.2ms
# video 1/1 (frame 36/50) /content/Sesion12_video.mp4: 384x640 7 persons, 2 chairs, 2 dining tables, 1 laptop, 1 oven, 7890.5ms
# video 1/1 (frame 37/50) /content/Sesion12_video.mp4: 384x640 8 persons, 4 chairs, 1 dining table, 1 oven, 6950.3ms
# video 1/1 (frame 38/50) /content/Sesion12_video.mp4: 384x640 8 persons, 4 chairs, 1 dining table, 1 tv, 1 laptop, 1 oven, 7904.4ms
# video 1/1 (frame 39/50) /content/Sesion12_video.mp4: 384x640 9 persons, 5 chairs, 1 dining table, 1 tv, 1 laptop, 7924.2ms
# video 1/1 (frame 40/50) /content/Sesion12_video.mp4: 384x640 10 persons, 4 chairs, 1 dining table, 1 tv, 6917.3ms
# video 1/1 (frame 41/50) /content/Sesion12_video.mp4: 384x640 9 persons, 5 chairs, 2 dining tables, 7983.6ms
# video 1/1 (frame 42/50) /content/Sesion12_video.mp4: 384x640 9 persons, 3 chairs, 3 dining tables, 1 tv, 7115.5ms
# video 1/1 (frame 43/50) /content/Sesion12_video.mp4: 384x640 9 persons, 3 chairs, 1 dining table, 1 tv, 7593.4ms
# video 1/1 (frame 44/50) /content/Sesion12_video.mp4: 384x640 11 persons, 3 chairs, 1 dining table, 1 tv, 7846.2ms
# video 1/1 (frame 45/50) /content/Sesion12_video.mp4: 384x640 11 persons, 4 chairs, 1 dining table, 1 tv, 6837.1ms
# video 1/1 (frame 46/50) /content/Sesion12_video.mp4: 384x640 10 persons, 2 chairs, 2 dining tables, 1 tv, 8018.7ms
# video 1/1 (frame 47/50) /content/Sesion12_video.mp4: 384x640 9 persons, 2 chairs, 4 dining tables, 1 tv, 1 laptop, 7697.0ms
# video 1/1 (frame 48/50) /content/Sesion12_video.mp4: 384x640 11 persons, 1 chair, 2 dining tables, 1 tv, 3 laptops, 7023.3ms
# video 1/1 (frame 49/50) /content/Sesion12_video.mp4: 384x640 11 persons, 1 chair, 1 dining table, 1 tv, 4 laptops, 7842.0ms
# video 1/1 (frame 50/50) /content/Sesion12_video.mp4: 384x640 12 persons, 1 chair, 1 dining table, 1 tv, 3 laptops, 6883.6ms
# Speed: 7.0ms preprocess, 7600.2ms inference, 32.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/segment/predict
# Video procesado guardado en:
# runs/segment

# %%
# # Codigo para mostrar video incrustado en el notebook (si el video es muy largo, mejor no ejecutarlo
# mp4 = open(output_video, 'rb').read()
# data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
# HTML(f'<video width=640 controls loop autoplay src="{data_url}"></video>')

# %% [markdown]
# # (C) Algunas pruebas adicionales por hacer:
# - Prueba con tu propio video o ajusta los umbrales de confianza.
# - Cambia a un modelo más grande (`yolov8s-seg.pt`, `yolov8m-seg.pt`, …) para mayor calidad.
