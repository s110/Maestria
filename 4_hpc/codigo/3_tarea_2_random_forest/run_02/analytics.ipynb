# %%
import pandas as pd

# %%
df = pd.read_csv('C:/maestria/repo sebas\Maestria/4_hpc/codigo/3_tarea_2_random_forest/run_02/results_rf_synth.csv')
# drop n_jobs == 2
# df = df[df['n_jobs'] != 2]
df
# Out:
#     n_jobs  n_samples  n_features  n_informative  n_redundant  n_classes  \
# 0        1     100000          40             20           10          2
# 1        2     100000          40             20           10          2
# 2        4     100000          40             20           10          2
# 3        8     100000          40             20           10          2
# 4       16     100000          40             20           10          2
# 5       32     100000          40             20           10          2
# 6        1     200000          40             20           10          2
# 7        2     200000          40             20           10          2
# 8        4     200000          40             20           10          2
# 9        8     200000          40             20           10          2
# 10      16     200000          40             20           10          2
# 11      32     200000          40             20           10          2
# ...

# %%
"""
Columns = '	n_jobs	n_samples	n_features	n_informative	n_redundant	n_classes	n_estimators	max_depth	test_size	reps	fit_time_s_avg	pred_time_s_avg	accuracy_avg	slurm_job_id	slurm_array_task_id'
"""

"""
    n_jobs  n_samples  n_features  n_informative  n_redundant  n_classes  \
0        1     100000          40             20           10          2   
1        2     100000          40             20           10          2   
2        4     100000          40             20           10          2   
3        8     100000          40             20           10          2   
4       16     100000          40             20           10          2   
5       32     100000          40             20           10          2   
6        1     200000          40             20           10          2   
7        2     200000          40             20           10          2   
8        4     200000          40             20           10          2   
9        8     200000          40             20           10          2   
10      16     200000          40             20           10          2   
11      32     200000          40             20           10          2   
12       1     400000          40             20           10          2   
13       2     400000          40             20           10          2   
14       4     400000          40             20           10          2   
15       8     400000          40             20           10          2   
16      16     400000          40             20           10          2   
17      32     400000          40             20           10          2   
18       1     800000          40             20           10          2   
19       2     800000          40             20           10          2   
20       4     800000          40             20           10          2   
21       8     800000          40             20           10          2   
22      16     800000          40             20           10          2   
23      32     800000          40             20           10          2   

    n_estimators  max_depth  test_size  reps  fit_time_s_avg  pred_time_s_avg  \
0            400         20        0.2     3        279.4752           1.1017   
1            400         20        0.2     3        146.2490           0.6275   
2            400         20        0.2     3         75.9624           0.3247   
3            400         20        0.2     3         39.7470           0.1901   
4            400         20        0.2     3         24.2908           0.1216   
5            400         20        0.2     3         17.8138           0.1276   
6            400         20        0.2     3        599.6922           2.3470   
7            400         20        0.2     3        322.7156           1.2896   
8            400         20        0.2     3        168.2840           0.6771   
9            400         20        0.2     3         93.1206           0.3798   
10           400         20        0.2     3         53.5557           0.2357   
11           400         20        0.2     3         39.0097           0.1914   
12           400         20        0.2     3       1303.3563           5.4006   
13           400         20        0.2     3        702.1969           2.9220   
14           400         20        0.2     3        333.0181           1.5252   
15           400         20        0.2     3        179.8400           0.8935   
16           400         20        0.2     3         99.5784           0.5869   
17           400         20        0.2     3         63.2757           0.3612   
18           400         20        0.2     3       2716.9230          11.6726   
19           400         20        0.2     3       1450.6279           5.9415   
20           400         20        0.2     3        756.5427           3.2139   
21           400         20        0.2     3        412.3907           1.8241   
22           400         20        0.2     3        229.7576           1.1520   
23           400         20        0.2     3        144.1867           0.7766   

    accuracy_avg  slurm_job_id  slurm_array_task_id  
0         0.9629         13846                    0  
1         0.9629         13850                    1  
2         0.9629         13852                    2  
3         0.9629         13854                    3  
4         0.9629         13855                    4  
5         0.9629         13856                    5  
6         0.9761         13857                    6  
7         0.9761         13858                    7  
8         0.9761         13862                    8  
9         0.9761         13864                    9  
10        0.9761         13865                   10  
11        0.9761         13866                   11  
12        0.9794         13867                   12  
13        0.9794         13871                   13  
14        0.9794         13877                   14  
15        0.9794         13880                   15  
16        0.9794         13881                   16  
17        0.9794         13883                   17  
18        0.9814         13884                   18  
19        0.9814         13896                   19  
20        0.9814         13902                   20  
21        0.9814         13904                   21  
22        0.9814         13905                   22  
23        0.9814         13845                   23  
"""
# Out:
# '\n    n_jobs  n_samples  n_features  n_informative  n_redundant  n_classes  0        1     100000          40             20           10          2   \n1        2     100000          40             20           10          2   \n2        4     100000          40             20           10          2   \n3        8     100000          40             20           10          2   \n4       16     100000          40             20           10          2   \n5       32     100000          40             20           10          2   \n6        1     200000          40             20           10          2   \n7        2     200000          40             20           10          2   \n8        4     200000          40             20           10          2   \n9        8     200000          40             20           10          2   \n10      16     200000          40             20           10          2   \n11      32     200000          40             20           10          2  
# ...

# %%
# plot fit_time_s_avg vs n_jobs for different n_samples, añadiendo línea ideal para n_samples=800000
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='n_jobs', y='fit_time_s_avg', hue='n_samples', marker='o')
plt.xscale('log', base=2)
plt.yscale('log')
plt.xlabel('Número of Jobs (n_jobs)')
plt.ylabel('Tiempo de entrenamiento promedio (s)')
plt.title('Tiempo de entrenamiento vs Número de Jobs para diferente tamaños de Sample')
plt.legend(title='Número of Samples (n_samples)')

# Línea ideal para n_samples=800000
n_samples_ideal = 800000
df_ideal = df[df['n_samples'] == n_samples_ideal].sort_values('n_jobs')
n_jobs_ideal = df_ideal['n_jobs'].values
fit_time_single_core = df_ideal[df_ideal['n_jobs'] == min(n_jobs_ideal)]['fit_time_s_avg'].values[0]
ideal_times = fit_time_single_core / n_jobs_ideal
plt.plot(n_jobs_ideal, ideal_times, 'k--', label='T=1/p')

plt.legend(title='Número de Samples (n_samples)')
plt.tight_layout()
plt.savefig('fit_time_vs_n_jobs_with_ideal.png')
plt.show()

# %%
# Calcular speedup para cada grupo de n_samples
df['speedup'] = df.groupby('n_samples')['fit_time_s_avg'].transform(lambda x: x.iloc[0] / x)

# Ahora puedes graficar
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='n_jobs', y='speedup', hue='n_samples', marker='o')

for n_samples in df['n_samples'].unique()[-1:]:
    subset = df[df['n_samples'] == n_samples]
    plt.plot(subset['n_jobs'], subset['n_jobs'], linestyle='--', label=f'Teórico')
plt.xlabel('Número de Jobs (n_jobs)')
plt.ylabel('Speedup')
plt.title('Speedup vs Número de Jobs')
plt.legend(title='Número de Samples (n_samples)')
plt.tight_layout()
plt.savefig('speedup_vs_n_jobs_theoretical.png')
plt.show()

# %%
# Calcular speedup y eficiencia
df['speedup'] = df.groupby('n_samples')['fit_time_s_avg'].transform(lambda x: x.iloc[0] / x)
df['efficiency'] = df['speedup'] / df['n_jobs']

# Graficar eficiencia y línea ideal
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='n_jobs', y='efficiency', hue='n_samples', marker='o')
plt.axhline(1, color='k', linestyle='--', label='Eficiencia Ideal = 1')
plt.xscale('log', base=2)
plt.xlabel('Número de Jobs (n_jobs)')
plt.ylabel('Eficiencia')
plt.title('Eficiencia vs Número de Jobs para diferentes tamaños de Sample')
plt.legend(title='Número de Samples (n_samples)')
plt.tight_layout()
plt.savefig('efficiency_vs_n_jobs.png')
plt.show()

# %%
# plot accuracy_avg vs n_jobs for different n_samples
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='n_jobs', y='accuracy_avg', hue='n_samples', marker='o')
plt.xscale('log', base=2)
plt.xlabel('Número de Jobs (n_jobs)')
plt.ylabel('Accuracy Promedio (accuracy_avg)')
plt.title('Accuracy vs Número de Jobs para diferentes tamaños de Sample')
# set ylim
plt.ylim(0.5, 1)
plt.legend(title='Número de Samples (n_samples)')
plt.tight_layout()
plt.savefig('accuracy_vs_n_jobs.png')
plt.show()
